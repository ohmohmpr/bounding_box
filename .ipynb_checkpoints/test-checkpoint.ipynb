# %%
# import iou.py in the same directory

import numpy as np
from iou import *
import matplotlib.pyplot as plt

# %%
# Create two line segments (2D)
line1 = np.array([[0, 0], [1, 1]])
line2 = np.array([[0, 1], [1, 0]])

# Plot the two lines
plt.plot(line1[:, 0], line1[:, 1], label='line1')
print("X: ",line1[:, 0])
print("Y: ",line1[:, 1])
plt.plot(line2[:, 0], line2[:, 1], label='line2')
# Out:
# X:  [0 1]
# Y:  [0 1]

# %%
# Plot line1, line2, and their intersection
intersection = find_intersection(line1, line2)
if intersection:
    plt.plot(intersection[0], intersection[1], 'ro', label='intersection')
    plt.plot(line1[:, 0], line1[:, 1], label='line1')
    plt.plot(line2[:, 0], line2[:, 1], label='line2')
    plt.legend()
    plt.show()

# %%
# Rotate the line1 by 90 degrees and translate it by (1, 1)
line1_transformed = transform_line_segment(line1, (1, 1), np.pi / 2)
# Plot the two lines
plt.plot(line1[:, 0], line1[:, 1], label='line1')
plt.plot(line1_transformed[:, 0], line1_transformed[:, 1], label='line1_transformed')
plt.plot(line2[:, 0], line2[:, 1], label='line2')
# plot with constant factor on the x-axis and y-axis
plt.axis('equal')
plt.title('Rotated and translated line segment by 90 degrees and (1, 1)')
plt.legend()

# %%
# Plot the box
box = np.array([0, 0, 0, 1, 1, 1, 0])
box_line_segments = compute_box_line_segments(box)
for i in range(len(box_line_segments)):
    plt.plot(box_line_segments[i][:, 0], box_line_segments[i][:, 1], label='line' + str(i))
plt.axis('equal')
plt.title('Box')
plt.legend()

box = np.array([1, 1, 2, 1, 1, 1, np.pi / 4])
box_line_segments = compute_box_line_segments(box)
for i in range(len(box_line_segments)):
    plt.plot(box_line_segments[i][:, 0], box_line_segments[i][:, 1], label='line' + str(i))
plt.axis('equal')
plt.title('Box')
plt.legend()

# %%
# Plot the two boxes
box1 = np.array([0, 0, 0, 1, 1, 1, 0.2])
box2 = np.array([0, 0, 2, 1, 1, 1, np.pi / 4])
box1_line_segments = compute_box_line_segments(box1)
box2_line_segments = compute_box_line_segments(box2)

# Plot the two boxes and line1
plt.plot(line1[:, 0], line1[:, 1], label='line1')
for i in range(len(box1_line_segments)):
    plt.plot(box1_line_segments[i][:, 0], box1_line_segments[i][:, 1], label='box1_line' + str(i))
for i in range(len(box2_line_segments)):
    plt.plot(box2_line_segments[i][:, 0], box2_line_segments[i][:, 1], label='box2_line' + str(i))
plt.axis('equal')
plt.title('Box1, Box2, and line1')
plt.legend()


# Plot intersection between line1 and box1
polygon_collection = compute_line_segment_box_intersection(line1, box1)
for i in range(len(polygon_collection)):
    plt.plot(polygon_collection[i][0], polygon_collection[i][1], 'ro', label='intersection')
plt.plot(line1[:, 0], line1[:, 1], label='line1')
for i in range(len(box1_line_segments)):
    plt.plot(box1_line_segments[i][:, 0], box1_line_segments[i][:, 1], label='box1_line' + str(i))
plt.axis('equal')
plt.title('Intersection between line1 and box1')
plt.legend()



# Plot intersection between box1 and box2

polygon_collection = compute_box_box_intersection(box1, box2)
for i in range(len(polygon_collection)):
    plt.plot(polygon_collection[i][0], polygon_collection[i][1], 'ro', label='intersection')
for i in range(len(box1_line_segments)):
    plt.plot(box1_line_segments[i][:, 0], box1_line_segments[i][:, 1], label='box1_line' + str(i))
for i in range(len(box2_line_segments)):
    plt.plot(box2_line_segments[i][:, 0], box2_line_segments[i][:, 1], label='box2_line' + str(i))
plt.axis('equal')
plt.title('Intersection between box1 and box2')
plt.legend()

# %%
# Compute intersection between box1-line2, box2-line1
lineb1l2 = compute_box_line_segments(box1)[0]
lineb2l1 = compute_box_line_segments(box2)[0]

plt.plot(lineb1l2[:, 0], lineb1l2[:, 1], label='lineb1l2')
plt.plot(lineb2l1[:, 0], lineb2l1[:, 1], label='lineb2l1')
plt.axis('equal')
plt.title('lineb1l2, lineb2l1')
plt.legend()

# Find intersection between lineb1l2 and lineb2l1
intersection = find_intersection(lineb1l2, lineb2l1)
plt.plot(intersection[0], intersection[1], 'ro', label='intersection')
plt.plot(lineb1l2[:, 0], lineb1l2[:, 1], label='lineb1l2')
plt.plot(lineb2l1[:, 0], lineb2l1[:, 1], label='lineb2l1')
plt.axis('equal')
plt.title('Intersection between lineb1l2 and lineb2l1')
plt.legend()

# %%
# Plot intersection between box1 and box2
polygon_collection = compute_box_box_intersection(box1, box2)
for i in range(len(polygon_collection)):
    plt.plot(polygon_collection[i][0], polygon_collection[i][1], 'ro', label='intersection')
for i in range(len(box1_line_segments)):
    plt.plot(box1_line_segments[i][:, 0], box1_line_segments[i][:, 1], label='box1_line' + str(i))
for i in range(len(box2_line_segments)):
    plt.plot(box2_line_segments[i][:, 0], box2_line_segments[i][:, 1], label='box2_line' + str(i))
plt.axis('equal')
plt.title('Intersection between box1 and box2')
plt.legend()

print("polygon_collection", polygon_collection)
# Out:
# polygon_collection [(-0.24700845048463338, 0.4600983307019141), (0.16374467070332444, 0.543362110483223), (0.4600983307019141, 0.24700845048463327), (0.543362110483223, -0.16374467070332432), (0.24700845048463338, -0.4600983307019141), (-0.16374467070332444, -0.543362110483223), (-0.543362110483223, 0.16374467070332432), (-0.4600983307019141, -0.24700845048463327)]

# %% [markdown]
# # NOTE, THERE IS A BUG! WHEN THE BOX IS PARALLEL TO X AXIS. INTERSECTION CALCULATION IS FAILING

# %%
print("Area of intersection between box1 and box2: ", calculate_polygon_area(polygon_collection))
# Out:
# Area of intersection between box1 and box2:  0.7164865396379254

# %% [markdown]
# ALMOST DONE # REMEMBER THIS IS ONLY 2D and I BELIVE THAT IS ALRIGHT FOR THE PROJECT

# %%
# Test with two new random boxes
box_a = np.array([0.5, 0, 0, 1, 1, 1, 0.2])
box_b = np.array([0, 0, 2, 1, 1, 1, 0.1])
print("Area of intersection between box_a and box_b: ", calculate_common_area(box_a, box_b))
box_a_line_segments = compute_box_line_segments(box_a)
box_b_line_segments = compute_box_line_segments(box_b)
polygon_collection = compute_box_box_intersection(box_a, box_b)
for i in range(len(polygon_collection)):
    plt.plot(polygon_collection[i][0], polygon_collection[i][1], 'ro', label='intersection')
for i in range(len(box_a_line_segments)):
    plt.plot(box_a_line_segments[i][:, 0], box_a_line_segments[i][:, 1], label='box_a_line' + str(i))
for i in range(len(box_b_line_segments)):
    plt.plot(box_b_line_segments[i][:, 0], box_b_line_segments[i][:, 1], label='box_b_line' + str(i))
plt.axis('equal')
plt.title('Intersection between box_a and box_b')
plt.legend()
# Out:
# Area of intersection between box_a and box_b:  ([(0.45229308111445193, 0.5004987512492974), array([-0.08936795,  0.39069862]), (0.089866705567449, -0.49349371276571796), array([ 0.54741879, -0.44758537])], 0.46838872850463587)

# %%
# Test with two new random boxes
box_a = np.array([0, 0, 0, 1, 1, 1, 1.1])
box_b = np.array([0, 0, 2, 1, 1, 1, 0.1])
print("Area of intersection between box_a and box_b: ", calculate_common_area(box_a, box_b))
box_a_line_segments = compute_box_line_segments(box_a)
box_b_line_segments = compute_box_line_segments(box_b)
polygon_collection = compute_box_box_intersection(box_a, box_b)
for i in range(len(polygon_collection)):
    plt.plot(polygon_collection[i][0], polygon_collection[i][1], 'ro', label='intersection')
for i in range(len(box_a_line_segments)):
    plt.plot(box_a_line_segments[i][:, 0], box_a_line_segments[i][:, 1], label='box_a_line' + str(i))
for i in range(len(box_b_line_segments)):
    plt.plot(box_b_line_segments[i][:, 0], box_b_line_segments[i][:, 1], label='box_b_line' + str(i))
plt.axis('equal')
plt.title('Intersection between box_a and box_b')
plt.legend()
# Out:
# Area of intersection between box_a and box_b:  ([(-0.5121480438466511, 0.09605437926996574), (-0.47023246059712553, -0.3217033347715781), (-0.09605437926996552, -0.5121480438466512), (0.3217033347715781, -0.47023246059712553), (0.5121480438466511, -0.09605437926996574), (0.47023246059712553, 0.3217033347715781), (0.09605437926996552, 0.5121480438466512), (-0.3217033347715781, 0.47023246059712553)], 0.8397104828698141)

# %%
# PENDING, NEED TO ADD POINTS THAT ARE INSIDE THE BOXES

# Checking is__point_inside_box function
box = np.array([0, 0, 0, 1, 1, 1, 0])
point = np.array([0.5, 0.5])
point2 = np.array([1.5, 1.5])
point3 = np.array([0.3, -0.2])
print("Is point inside box? ", is_point_inside_box(point, box))
print("Is point2 inside box? ", is_point_inside_box(point2, box))
print("Is point3 inside box? ", is_point_inside_box(point3, box))
# Plot the box
box = np.array([0, 0, 0, 1, 1, 1, 0])
box_line_segments = compute_box_line_segments(box)
for i in range(len(box_line_segments)):
    plt.plot(box_line_segments[i][:, 0], box_line_segments[i][:, 1], label='line' + str(i))
# Plot the point
plt.plot(point[0], point[1], 'ro', label='point')
plt.plot(point2[0], point2[1], 'ro', label='point2')  
plt.plot(point3[0], point3[1], 'ro', label='point3')  
plt.axis('equal')
plt.title('Box')
plt.legend()
# Out:
# Is point inside box?  True
# Is point2 inside box?  False
# Is point3 inside box?  True

# %%
# Given two boxes, compute all the vertices that are inside the other box
box1 = np.array([0, 0, 0, 1, 1, 1, 0.01])
box2 = np.array([0.2, 0.2, 0, 1, 1, 1, 1])
box1_line_segments = compute_box_line_segments(box1)
box2_line_segments = compute_box_line_segments(box2)



polygon_collection = polygon_of_intersection(box1, box2)
for i in range(len(polygon_collection)):
    plt.plot(polygon_collection[i][0], polygon_collection[i][1], 'ro', label='intersection')
for i in range(len(box1_line_segments)):
    plt.plot(box1_line_segments[i][:, 0], box1_line_segments[i][:, 1], label='box1_line' + str(i))
for i in range(len(box2_line_segments)):
    plt.plot(box2_line_segments[i][:, 0], box2_line_segments[i][:, 1], label='box2_line' + str(i))
plt.axis('equal')
plt.title('Intersection between box1 and box2')
plt.legend()

# %%
# Test with two new random boxes
box_a = np.array([0, 0, 0, 1, 1, 1, 1.1])
box_b = np.array([0, 0, 2, 1, 1, 1, 0.1])
print("Area of intersection between box_a and box_b: ", calculate_common_area(box_a, box_b))
box_a_line_segments = compute_box_line_segments(box_a)
box_b_line_segments = compute_box_line_segments(box_b)
polygon_collection = polygon_of_intersection(box_a, box_b)
for i in range(len(polygon_collection)):
    plt.plot(polygon_collection[i][0], polygon_collection[i][1], 'ro', label='intersection')
for i in range(len(box_a_line_segments)):
    plt.plot(box_a_line_segments[i][:, 0], box_a_line_segments[i][:, 1], label='box_a_line' + str(i))
for i in range(len(box_b_line_segments)):
    plt.plot(box_b_line_segments[i][:, 0], box_b_line_segments[i][:, 1], label='box_b_line' + str(i))
plt.axis('equal')
plt.title('Intersection between box_a and box_b')
plt.legend()
# Out:
# Area of intersection between box_a and box_b:  ([(-0.5121480438466511, 0.09605437926996574), (-0.47023246059712553, -0.3217033347715781), (-0.09605437926996552, -0.5121480438466512), (0.3217033347715781, -0.47023246059712553), (0.5121480438466511, -0.09605437926996574), (0.47023246059712553, 0.3217033347715781), (0.09605437926996552, 0.5121480438466512), (-0.3217033347715781, 0.47023246059712553)], 0.8397104828698141)

# %%
# Test with two new random boxes
box_a = np.array([0.5, 0, 0, 1, 1, 1, 0.2])
box_b = np.array([0, 0, 2, 1, 1, 1, 0.1])
print("Area of intersection between box_a and box_b: ", calculate_common_area(box_a, box_b))
box_a_line_segments = compute_box_line_segments(box_a)
box_b_line_segments = compute_box_line_segments(box_b)
polygon_collection = polygon_of_intersection(box_a, box_b)
for i in range(len(polygon_collection)):
    plt.plot(polygon_collection[i][0], polygon_collection[i][1], 'ro', label='intersection')
for i in range(len(box_a_line_segments)):
    plt.plot(box_a_line_segments[i][:, 0], box_a_line_segments[i][:, 1], label='box_a_line' + str(i))
for i in range(len(box_b_line_segments)):
    plt.plot(box_b_line_segments[i][:, 0], box_b_line_segments[i][:, 1], label='box_b_line' + str(i))
plt.axis('equal')
plt.title('Intersection between box_a and box_b')
plt.legend()
# Out:
# Area of intersection between box_a and box_b:  ([(0.45229308111445193, 0.5004987512492974), array([-0.08936795,  0.39069862]), (0.089866705567449, -0.49349371276571796), array([ 0.54741879, -0.44758537])], 0.46838872850463587)

# %%
# Test with two new random boxes
box_a = np.array([0, 0, 0, 1, 1, 1, 0])
box_b = np.array([0, 0, 2, 1, 1, 1, 0])
print("Area of intersection between box_a and box_b: ", calculate_common_area(box_a, box_b))
box_a_line_segments = compute_box_line_segments(box_a)
box_b_line_segments = compute_box_line_segments(box_b)
polygon_collection = polygon_of_intersection(box_a, box_b)
for i in range(len(polygon_collection)):
    plt.plot(polygon_collection[i][0], polygon_collection[i][1], 'ro', label='intersection')
for i in range(len(box_a_line_segments)):
    plt.plot(box_a_line_segments[i][:, 0], box_a_line_segments[i][:, 1], label='box_a_line' + str(i))
for i in range(len(box_b_line_segments)):
    plt.plot(box_b_line_segments[i][:, 0], box_b_line_segments[i][:, 1], label='box_b_line' + str(i))
plt.axis('equal')
plt.title('Intersection between box_a and box_b')
plt.legend()
# Out:
# Area of intersection between box_a and box_b:  ([(-0.5000499974999166, 0.49994999750008334), (-0.49994999750008334, -0.5000499974999166), (0.5000499974999166, -0.49994999750008334), (0.49994999750008334, 0.5000499974999166)], 1.0)

# %%
# Test with two new random boxes
box_a = np.array([0.5, 0, 0, 1, 1, 1, 0.2])
box_b = np.array([0, 0, 2, 1, 1, 1, 0.1])
print("Area of intersection between box_a and box_b: ", calculate_common_area(box_a, box_b))
# Out:
# Area of intersection between box_a and box_b:  ([(0.45229308111445193, 0.5004987512492974), array([-0.08936795,  0.39069862]), (0.089866705567449, -0.49349371276571796), array([ 0.54741879, -0.44758537])], 0.46838872850463587)

# %%
print(len(([(0.45229308111445193, 0.5004987512492974), (0.089866705567449, -0.49349371276571796), np.array([-0.08936795,  0.39069862]), np.array([-0.08936795,  0.39069862]), np.array([ 0.54741879, -0.44758537]), np.array([ 0.54741879, -0.44758537])])))
a = [(0.45229308111445193, 0.5004987512492974), (0.089866705567449, -0.49349371276571796), np.array([-0.08936795,  0.39069862]), np.array([ 0.54741879, -0.44758537])]
b = [([0.49994999750008334, 0.5000499974999166]), (-0.5000499974999166, 0.49994999750008334), (0.5000499974999166, -0.49994999750008334), (-0.49994999750008334, -0.5000499974999166)]
c = [(0.45229308111445193, 0.5004987512492974), (0.089866705567449, -0.49349371276571796), ([-0.08936795,  0.39069862]), ([ 0.54741879, -0.44758537])]
d = [(0.5,0.5), (0.5,-0.5), ( -0.5,-0.5), (-0.5,0.5)]

for i in range(len(a)):
    plt.plot(a[i][0], a[i][1], 'ro', label='intersection')
    #compute area of a
    print("Area of polygon: ", calculate_polygon_area(a))

for i in range(len(b)):
    plt.plot(b[i][0], b[i][1], 'ro', label='intersection')
    #compute area of b
    print("Area of polygon: ", calculate_polygon_area(b))

for i in range(len(c)):
    plt.plot(c[i][0], c[i][1], 'ro', label='intersection')
    #compute area of c
    print("Area of polygon: ", calculate_polygon_area(c))

for i in range(len(d)):
    plt.plot(d[i][0], d[i][1], 'ro', label='intersection')
    #compute area of d
    print("Area of polygon: ", calculate_polygon_area(d))
# Out:
# 6
# Area of polygon:  0.01268625932242462
# Area of polygon:  0.01268625932242462
# Area of polygon:  0.01268625932242462
# Area of polygon:  0.01268625932242462
# Area of polygon:  0.0
# Area of polygon:  0.0
# Area of polygon:  0.0
# Area of polygon:  0.0
# Area of polygon:  0.01268625932242462
# Area of polygon:  0.01268625932242462
# Area of polygon:  0.01268625932242462
# Area of polygon:  0.01268625932242462
# Area of polygon:  1.0
# Area of polygon:  1.0
# Area of polygon:  1.0
# Area of polygon:  1.0

# %%
# Testing for two boxes
box1 = np.array([0, 0, 0, 10, 10, 2, 0])
box2 = np.array([5,5,0, 10, 10, 2, 0])
box1_line_segments = compute_box_line_segments(box1)
box2_line_segments = compute_box_line_segments(box2)
polygon_collection = polygon_of_intersection(box1, box2)
for i in range(len(polygon_collection)):
    plt.plot(polygon_collection[i][0], polygon_collection[i][1], 'ro', label='intersection')
for i in range(len(box1_line_segments)):
    plt.plot(box1_line_segments[i][:, 0], box1_line_segments[i][:, 1], label='box1_line' + str(i))
for i in range(len(box2_line_segments)):
    plt.plot(box2_line_segments[i][:, 0], box2_line_segments[i][:, 1], label='box2_line' + str(i))
plt.axis('equal')
plt.title('Intersection between box1 and box2')
plt.legend()

# Calulate area of intersection
print("Area of intersection between box1 and box2: ", calculate_polygon_area(polygon_collection))
# Calculate iou 
print("IoU between box1 and box2: ", calculate_iou(box1, box2))
print("Percentage overlap between box1 and box2: ", calculate_percent_overlap(box1, box2))
# Out:
# Area of intersection between box1 and box2:  25.000000000006718
# IoU between box1 and box2:  0.14285714285718673
# Percentage overlap between box1 and box2:  (0.25000000000006717, 0.25000000000006717)

# %%
# Testing for two boxes
box1 = np.array([0, 0, 0, 10, 30, 2, 0])
box2 = np.array([-5,8,0, 10, 10, 2, 1])
box1_line_segments = compute_box_line_segments(box1)
box2_line_segments = compute_box_line_segments(box2)
polygon_collection = polygon_of_intersection(box1, box2)
for i in range(len(polygon_collection)):
    plt.plot(polygon_collection[i][0], polygon_collection[i][1], 'ro', label='intersection')
for i in range(len(box1_line_segments)):
    plt.plot(box1_line_segments[i][:, 0], box1_line_segments[i][:, 1], label='box1_line' + str(i))
for i in range(len(box2_line_segments)):
    plt.plot(box2_line_segments[i][:, 0], box2_line_segments[i][:, 1], label='box2_line' + str(i))
plt.axis('equal')
plt.title('Intersection between box1 and box2')
plt.legend()

# Calulate area of intersection
print("Area of intersection between box1 and box2: ", calculate_polygon_area(polygon_collection))
# Calculate iou 
print("IoU between box1 and box2: ", calculate_iou(box1, box2))
print("Percentage overlap between box1 and box2: ", calculate_percent_overlap(box1, box2))
# Out:
# Area of intersection between box1 and box2:  50.00950806847038
# IoU between box1 and box2:  0.1428881904547681
# Percentage overlap between box1 and box2:  (0.16669836022823462, 0.5000950806847038)

# %%
# Testing for two boxes
box1 = np.array([0, 0, 0, 10, 30, 2, 0])
box2 = np.array([-5,8,0, 10, 30, 2, 0.2])
box1_line_segments = compute_box_line_segments(box1)
box2_line_segments = compute_box_line_segments(box2)
polygon_collection = polygon_of_intersection(box1, box2)
for i in range(len(polygon_collection)):
    plt.plot(polygon_collection[i][0], polygon_collection[i][1], 'ro', label='intersection')
for i in range(len(box1_line_segments)):
    plt.plot(box1_line_segments[i][:, 0], box1_line_segments[i][:, 1], label='box1_line' + str(i))
for i in range(len(box2_line_segments)):
    plt.plot(box2_line_segments[i][:, 0], box2_line_segments[i][:, 1], label='box2_line' + str(i))
plt.axis('equal')
plt.title('Intersection between box1 and box2')
plt.legend()

# Calulate area of intersection
print("Area of intersection between box1 and box2: ", calculate_polygon_area(polygon_collection))
# Calculate iou 
print("IoU between box1 and box2: ", calculate_iou(box1, box2))
print("Percentage overlap between box1 and box2: ", calculate_percent_overlap(box1, box2))
# Out:
# Area of intersection between box1 and box2:  126.02388593914878
# IoU between box1 and box2:  0.26588657571670216
# Percentage overlap between box1 and box2:  (0.42007961979716263, 0.42007961979716263)

# %%
# Testing for two boxes
box1 = np.array([0, 0, 0, 10, 30, 2, 0])
box2 = np.array([-1,2,0, 10, 30, 2, 0.2])
box1_line_segments = compute_box_line_segments(box1)
box2_line_segments = compute_box_line_segments(box2)
polygon_collection = polygon_of_intersection(box1, box2)
for i in range(len(polygon_collection)):
    plt.plot(polygon_collection[i][0], polygon_collection[i][1], 'ro', label='intersection')
for i in range(len(box1_line_segments)):
    plt.plot(box1_line_segments[i][:, 0], box1_line_segments[i][:, 1], label='box1_line' + str(i))
for i in range(len(box2_line_segments)):
    plt.plot(box2_line_segments[i][:, 0], box2_line_segments[i][:, 1], label='box2_line' + str(i))
plt.axis('equal')
plt.title('Intersection between box1 and box2')
plt.legend()

# Calulate area of intersection
print("Area of intersection between box1 and box2: ", calculate_polygon_area(polygon_collection))
# Calculate iou 
print("IoU between box1 and box2: ", calculate_iou(box1, box2))
print("Percentage overlap between box1 and box2: ", calculate_percent_overlap(box1, box2))
# Out:
# Area of intersection between box1 and box2:  239.13609546620634
# IoU between box1 and box2:  0.6626766835412659
# Percentage overlap between box1 and box2:  (0.7971203182206879, 0.7971203182206879)

# %%
# Testing for two boxes
box1 = np.array([0, 0, 0, 10, 30, 2, 0])
box2 = np.array([-1,35,0, 10, 30, 2, 0.2])
box1_line_segments = compute_box_line_segments(box1)
box2_line_segments = compute_box_line_segments(box2)
polygon_collection = polygon_of_intersection(box1, box2)
for i in range(len(polygon_collection)):
    plt.plot(polygon_collection[i][0], polygon_collection[i][1], 'ro', label='intersection')
for i in range(len(box1_line_segments)):
    plt.plot(box1_line_segments[i][:, 0], box1_line_segments[i][:, 1], label='box1_line' + str(i))
for i in range(len(box2_line_segments)):
    plt.plot(box2_line_segments[i][:, 0], box2_line_segments[i][:, 1], label='box2_line' + str(i))
plt.axis('equal')
plt.title('Intersection between box1 and box2')
plt.legend()

# Calulate area of intersection
print("Area of intersection between box1 and box2: ", calculate_polygon_area(polygon_collection))
# Calculate iou 
print("IoU between box1 and box2: ", calculate_iou(box1, box2))
print("Percentage overlap between box1 and box2: ", calculate_percent_overlap(box1, box2))
# Out:
# Area of intersection between box1 and box2:  0
# IoU between box1 and box2:  0.0
# Percentage overlap between box1 and box2:  (0.0, 0.0)

# %%
# Testing for two boxes
box1 = np.array([0, 0, 0, 10, 30, 2, 0])
box2 = np.array([-1,24,0, 10, 30, 2, 7])
box1_line_segments = compute_box_line_segments(box1)
box2_line_segments = compute_box_line_segments(box2)
polygon_collection = polygon_of_intersection(box1, box2)
for i in range(len(polygon_collection)):
    plt.plot(polygon_collection[i][0], polygon_collection[i][1], 'ro', label='intersection')
for i in range(len(box1_line_segments)):
    plt.plot(box1_line_segments[i][:, 0], box1_line_segments[i][:, 1], label='box1_line' + str(i))
for i in range(len(box2_line_segments)):
    plt.plot(box2_line_segments[i][:, 0], box2_line_segments[i][:, 1], label='box2_line' + str(i))
plt.axis('equal')
plt.title('Intersection between box1 and box2')
plt.legend()

# Calulate area of intersection
print("Area of intersection between box1 and box2: ", calculate_polygon_area(polygon_collection))
# Calculate iou 
print("IoU between box1 and box2: ", calculate_iou(box1, box2))
print("Percentage overlap between box1 and box2: ", calculate_percent_overlap(box1, box2))
# Out:
# Area of intersection between box1 and box2:  13.154074548056371
# IoU between box1 and box2:  0.022414869009998003
# Percentage overlap between box1 and box2:  (0.043846915160187905, 0.043846915160187905)
